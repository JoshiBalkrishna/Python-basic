# %% [markdown]
# 1.In the below elements which of them are values or an expression? eg:- values can be
# integer or string and expressions will be mathematical operators.
# *,'hello',-87.8,-,/,+,6
# =>
#     *----->expression
#     'hello'---->value
#     -87.8 ----->value
#     - ----->expression
#     / ----->expression
#     + ----->expression
#     6 ----->value

# %% [markdown]
# 2.What is the difference between string and variable?
# =>
#     String : String is a representation of text.In python string can be written in double quotes or in single quotes.
#     Variable : Variables are containers for storing data values.

# %% [markdown]
# 3.Describe three different data types.
# =>
#     1.Integer : Integer store only numerical value.
#     2.Float   : Float store floating value.
#     3.String  : String is a representation of text.In python string can be written in double quotes or in single quotes.

# %% [markdown]
# 4.What is an expression made up of? What do all expressions do?
# =>
#     Expression is made up of values, containers and mathematical operators (operands).
#     e.g a=1+2
#     Expressions are used to evaluate the values or represent the result on the screen.

# %% [markdown]
# 5.This assignment statements, like spam = 10. What is the difference between an expression and a statement?
# =>
#     Expression is made up of values, containers, and mathematical operators (operands) and the statement is just like a command that a python interpreter executes like print.

# %% [markdown]
# 6.After running the following code, what does the variable bacon contain?
# bacon = 22
# bacon + 1
# =>23

# %% [markdown]
# 7.What should the values of the following two terms be?
# a)'spam' + 'spamspam'
# b)'spam' * 3
# =>
#     a)'spam' + 'spamspam' : return spamspamspam
#     b)'spam' * 3          : return spamspamspam
#     both return same output

# %% [markdown]
# 8.Why is eggs a valid variable name while 100 is invalid?
# =>
#     In python integer value is not valid but string value is valid for variable. For this reason eggs is valid variable name and 100 is invalid.

# %% [markdown]
# 9.What three functions can be used to get the integer, floating-point number, or string
# version of a value?
# =>
#     int()
#     float()
#     str()

# %% [markdown]
# 10.Why does this expression cause an error? How can you fix it?
# 'I have eaten ' + 99 + ' burritos.'
# =>
#     Because 99 is an integer and it cannot be concatenated with strings, if we have to concatenate it we need to do typecasting of integer value 99.
